# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py37_23.1.0-1-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local

# %%
# !python3.7 --version

# %%
# !wget https://github.com/ultralytics/yolov5/archive/refs/tags/v6.2.zip
# !unzip v6.2.zip
# !mv yolov5-6.2 yolov5
# !cd yolov5 && python3.7 -m pip install -r requirements.txt

# %% [markdown]
# ### Go to the link below, right click on Download, copy link and change the wget URL
# https://www.mediafire.com/file/8190hvvlsklr792/datasets.zip/file

# %%
# !wget https://download1648.mediafire.com/jukcz3yp2eig_kpQEtK2NAkyCkR5fCWMF3PEo6njXaOQZZO0z_oyJVnqtcTxRI7FUz6TCeQkSDrGFWsl5KHOGCB3D9Ont6kGiyKq6DYP5Aamj6tzlYEtTHmSpCcUP9wgUwO1-5UF0RjRNv9d5Az6Z8CXjf5F5HOJk-tYlWA/8190hvvlsklr792/datasets.zip
# !unzip datasets.zip
# !rm datasets.zip
# %cd yolov5

# %% [markdown]
# ### Go to the link below, right click on Download, copy link and change the wget URL
# https://www.mediafire.com/file/gsm3w30ddglowju/grocereye.yaml/file

# %%
# !cd data && wget https://download1647.mediafire.com/oke6n42hqwrg02Nyr8fWzhk-feErVpXL83LkgzLvfWTeuKlcO4IMH1vUu9VXapuARgI_68KXaTkOiUMqHZjeNn4eZ8_DJYNrjgjX8idyew3u6FIcp4c4gXGTnGOatyL20JhZPXf4Fv-rL6t3udur5rguNMLp7fcVg0ZSk4I/gsm3w30ddglowju/grocereye.yaml

# %%
# Train YOLOv5s on GrocerEye for 90 epoch (~5500 steps using 64 batches)
# !python3.7 train.py --img 640 --batch 64 --epochs 90 --data grocereye.yaml --weights yolov5s.pt

# %% [markdown]
# #### Go to yolov5 -> runs -> train -> exp -> weights -> best.pt
#
# That's your trained model!
